# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pandas.read_csv('pH.csv')

# %%
sns.lineplot(x="Time/d", y="100ml/min", marker='.', data=data)
sns.lineplot(x="Time/d", y="300ml/min", marker='o', data=data)
sns.lineplot(x="Time/d", y="500ml/min", marker='v', data=data)
sns.lineplot(x="Time/d", y="700ml/min", marker='1', data=data)
sns.lineplot(x="Time/d", y="900ml/min", marker='2', data=data)
# Out:
# <AxesSubplot: xlabel='Time/d', ylabel='100ml/min'>
