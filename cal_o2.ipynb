# %%
import pandas
import numpy as np
import datetime

# %%
path_pre = 'data_o2-1'

for i in range(1, 6):
    data = pandas.read_csv(path_pre + '/' + 'CO2-' + str(i) + '.csv')
    data['Time'] = data['Time'].astype('datetime64[ns]')
    data['O2'] = (data['Value'] - 400) * (i *0.02 - 0.01) * 1.429 / 1000000
    # data['O2'] = (data['Value'] - 400) * 0.03 / 1000000
    data['newindex'] = np.arange(len(data)-1, -1, -1)
    data.sort_values('newindex', inplace=True)
    data.drop('newindex', axis=1, inplace=True)
    # Initialize a dictionary to accumulate the oxygen consumption for each day
    daily_oxygen_consumption = {}
    
    index = 0
    last_time = ''
    # Loop through the data, group by date, and accumulate the oxygen consumption for each day
    two_hours = datetime.timedelta(hours=2)
    ten_hours = datetime.timedelta(hours=12)
    
    is_dan = 1
    for item in data.values:
        if is_dan == 0:
            is_dan = 1
            continue
        if is_dan == 1:
            is_dan = 0
        if i == 3:
            timestamp = timestamp + ten_hours

        timestamp = item[0] + two_hours
        if index == 0:
            # Convert the timestamp string to a datetime object
            # Get the date portion
            date = timestamp.date()
            # If this date is not in the dictionary yet, add it with 0 oxygen consumption
            if date not in daily_oxygen_consumption:
                daily_oxygen_consumption[date] = 0
            # Add the oxygen consumption for this data point to the total for this date
            daily_oxygen_consumption[date] += item[2]
        else:
            # Get the date portion
            date = timestamp.date()
            # If this date is not in the dictionary yet, add it with 0 oxygen consumption
            if date not in daily_oxygen_consumption:
                daily_oxygen_consumption[date] = 0
            # Add the oxygen consumption for this data point to the total for this date
            minites = int((timestamp - last_time).total_seconds() / 60)
            daily_oxygen_consumption[date] += item[2] * minites

        last_time = timestamp
        index += 1


    # Print the daily oxygen consumption
    print('data{}'.format(i))
    for date, consumption in daily_oxygen_consumption.items():
        print(f"{date}: {consumption} mg")
# Out:
# data1
# 2022-10-26: 0.008806412559999992 mg
# 2022-10-27: 0.08806341110000003 mg
# 2022-10-28: 0.06227804924 mg
# 2022-10-29: 0.03809892625 mg
# 2022-10-30: 0.001930693320000001 mg
# 2022-10-31: 0.001588947969999998 mg
# 2022-11-01: 0.0015710997599999994 mg
# 2022-11-02: 0.0027328767600000073 mg
# 2022-11-03: 8.649737e-05 mg
# data2
# 2022-10-26: 0.02567908713000005 mg
# 2022-10-27: 0.15837189731999987 mg
# 2022-10-28: 0.3423298967400008 mg
# 2022-10-29: 0.15057641652000023 mg
# 2022-10-30: 0.04408780808999996 mg
# 2022-10-31: 0.015304632869999977 mg
# 2022-11-01: 0.006117806219999975 mg
# data3
# 2022-11-12: 0.0 mg
# 2022-11-14: 0.0091608903 mg
# 2022-11-15: 0.28359548170000004 mg
# 2022-11-16: 0.539146624050001 mg
# 2022-11-17: 0.023032264750000003 mg
# 2022-11-18: 0.0019271494 mg
# data4
# 2022-10-26: 0.09376162004999988 mg
# 2022-10-27: 0.9672624917199998 mg
# 2022-10-28: 0.8827025313399993 mg
# 2022-10-29: 0.5055150090200003 mg
# 2022-10-30: 0.17912622175000026 mg
# 2022-10-31: 0.02299079516999997 mg
# 2022-11-02: 0.0009698908800000001 mg
# data5
# 2022-10-26: 0.06373101357000009 mg
# 2022-10-27: 0.3539276464500004 mg
# 2022-10-28: 0.7417402982100004 mg
# 2022-10-29: 0.14612719644000002 mg
# 2022-10-30: 0.06038162333999998 mg
# 2022-10-31: 0.0010098457200000007 mg
# 2022-11-01: 0.007345817370000001 mg
# 2022-11-02: 0.006187812929999998 mg
